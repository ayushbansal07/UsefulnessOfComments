# %%
import os

# %%
all_files = os.listdir("DATA/CSV/")

# %%
all_files
# Out:
# ['Projects_useless_data_Tic_Tac_Toe.c',
#  'DATA_Projects_libpng-code_contrib_powerpc-vsx_linux_aux.c_excel.csv',
#  'DATA_Projects_libpng-code_pngrtran.c_feature.csv',
#  'Projects_libpng-code_contrib_gregbook_rpng2-x.c',
#  'DATA_Projects_libpng-code_pngmem.c_excel.csv',
#  'DATA_Projects_libpng-code_intel_intel_init.c_train.csv',
#  'Projects_libpng-code_pngget.c_excel.csv',
#  'Projects_server_mariadb_unittest_json_lib_json_lib-t.c_train.csv',
#  'DATA_Projects_libpng-code_contrib_libtests_pngvalid.c_excel.csv',
#  'Projects_libpng-code_contrib_gregbook_wpng.c',
#  'Projects_libpng-code_intel_filter_sse2_intrinsics.c',
#  'Projects_useless_data_greedy.c_feature.csv',
#  'Projects_libpng-code_intel_filter_sse2_intrinsics.c_categories.csv',
#  'DATA_Projects_libpng-code_contrib_libtests_pngstest.c_feature.csv',
#  'Projects_libpng-code_pngpread.c_categories.csv',
#  'Projects_libpng-code_pngrtran.c_feature.csv',
#  'Projects_useless_data_greedy.c',
# ...

# %%
for file in all_files:
    if not file[:5] == "DATA_":
        continue
    if not file.endswith("_train.csv"):
        continue
    if file[5:] in all_files:
        print(file)
# Out:
# DATA_Projects_libpng-code_pngwtran.c_train.csv
# DATA_Projects_libpng-code_pngset.c_train.csv
# DATA_Projects_libpng-code_pngwio.c_train.csv
# DATA_Projects_libpng-code_contrib_powerpc-vsx_linux_aux.c_train.csv
# DATA_Projects_libpng-code_pngerror.c_train.csv
# DATA_Projects_libpng-code_pngwutil.c_train.csv
# DATA_Projects_libpng-code_pngtrans.c_train.csv

# %%
for file in all_files:
    if not file.endswith("_train.csv"):
        continue
    if not "libpng-code" in file:
        continue
    if not file[:5] == "DATA_":
        print(file)
# Out:
# Projects_libpng-code_contrib_tools_pngcp.c_train.csv
# Projects_libpng-code_contrib_powerpc-vsx_linux.c_train.csv
# Projects_libpng-code_contrib_gregbook_readpng.c_train.csv
# Projects_libpng-code_contrib_gregbook_rpng2-x.c_train.csv
# Projects_libpng-code_contrib_gregbook_wpng.c_train.csv
# Projects_libpng-code_intel_filter_sse2_intrinsics.c_train.csv
